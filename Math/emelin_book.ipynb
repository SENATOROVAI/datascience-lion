# %%
"""Описание модуля."""
# Out:
# 'Описание модуля.'

# %% [markdown]
# 1.4. Порядок действий
#
# ![image.png](attachment:image.png)
#
# Ответы:
#  1. Модуль числа - это расстояние этого числа от нуля на числовой прямой, независимо от знака числа.
# Поэтому:
# * модуль 4 = 4
# * модуль -1 = 1
# * модуль - 10/3 = примерно 3.33 (числительно делим на знаменатель)
# * расстояние между следующими числами: 3 и –2 = 5
# *  расстояние между следующими числами–7 и –13 = 6
#
# 2. Выполнить возведение в степень:
# * 2^5 = 2*2*2*2*2 = 32
# * 5^2 = 25
# * 10^0 = 1 (Правило. Все что в степенени 0=1)
#
# 3. Извлечь корни (полностью или частично), если это возможно:
# * √12 = 4
# * √20 = √4 * 5 = 2√5
# * √43 (нифига не понял, как можно посчитать. Но нашел имбовую формулу x_(n+1) = (x_n + a/x_n) / 2 ) Где a - число, из которого извлекается корень,= x_n-текущее приближение. Текущее приблежение это 36 (так как 43 находится между 36 и 49) х_1 = (6 + 43/6) / 2 = 6,58. И надо еще раз лупануть, а желательно еще 3 раза, для более точного результата. х_2 = (6.58 + 43/6.58) / 2 = 6,55
# * √49 = 7
# * √72 = х_1 = (8 + 72/8) / 2 = 8,5 и еще раз х_2 = (8,5 + 72/8,5) / 2 = 8,48
# * √121 = 11
# * √1000 = √1000 = 10^3? 4 * 25 √10 = 100√10?
# * √1875 = 25 * 25√3 = 625√3
# * 3√-81 = 3 * (-9) = -27?
# * 4√-16 = 4√(-4)^2 = 2√-4  = 2√(-2)^2 = -2
#
# 4.Избавиться от иррациональности в знаменателе:
# * 6*√3 / √3 * √3 = 6√3 / √3 * 3 = 6√3 / √9 = 6√3 / 3 = 2√3 ?
# * -1 / √7 = -1 * √7 / √7 * √7 = -1√7 / √49 = -√7 / 7 ?
# * 1 / 4√2 = 1 / √ 16 * 2 = 1 / √32 = 1 * √32 / √32 * √32 = √32 / √1024 = √32 / 4 * 4√64 = √32 / 4 * 4 * 8 = √32 / 128
#
# 5.Выполнить действия:
# * 3 * 2^2 + 1 = 29
# * 3 * (2^2 + 1) = 15
# * 6 * 5 / 3 = 10
# * решал на листке (-8)
# * √13 - 2 * 7 = √-1 ?
# * -2 (х-√9 - (3(1-2))) = -2х

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 1. 6 / 4 = 3 /2  или 1,5
# 2. 15 / 10 = 3 / 2 или 1,5
